# %% [markdown]
# # ===============5월4일(76일차) ================
# - 1교시 : 복습
# - 2교시 : 2_명암비(Contrast)조정
# - 3교시 : 2_채도(Saturation)변환
# - 4교시 : 2_Filter --> 여기 집중이 흐려짐
# - 5교시 : 2_Filter_Blurring
# - 6교시 : 2_Filter_Gaussian Blur, 잡음제거
# - 7교시 : 2_Filter_잡음제거_코드, 샤프닝

# %% [markdown]
# # ===============5월6일(77일차) ================
# - 1교시 : 복습
# - 2교시 :
# - 3교시 :
# - 4교시 :
# - 5교시 :
# - 6교시 :
# - 7교시 :
