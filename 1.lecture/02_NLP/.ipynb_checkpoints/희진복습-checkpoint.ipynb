# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /opt/anaconda3
# api                      /opt/anaconda3/envs/api
# ml                       /opt/anaconda3/envs/ml
# tf2                   *  /opt/anaconda3/envs/tf2

# %% [markdown]
# # =======62일차 02.KONLPY 코엔엘파이 ===========
# - 수업 :
# - 복습 : (1회-4월28일수)
# ## 1) 코엔엘파이 적용배경 및 정의
# ## 2) 코엔엘파이 설치
# ## 3) 코엔엘파이 형태소 분석기
# ## 4) 연습1 - 코엔엘파이말뭉치 --> kolaw, kobill 로 예시
# ## 5) 연습2 - 연습해보기

# %% [markdown]
# # 62.1 적용배경 및 정의

# %%
# 설치해보기 
# !pip install nltk
# !conda install -y nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /opt/anaconda3/envs/tf2/lib/python3.7/site-packages (from nltk) (0.17.0)
# Collecting regex
#   Using cached regex-2021.4.4-cp37-cp37m-macosx_10_9_x86_64.whl (285 kB)
# Collecting tqdm
#   Using cached tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Collecting click
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-7.1.2 nltk-3.6.2 regex-2021.4.4 tqdm-4.60.0

# %% [markdown]
# - 정규식 표현으로 nltk의 토큰을 만들어 볼 것이다.
# - 정규식 표현의 r'\w+' 의미는 ?
# - nltk의 정규식 표현 토큰을 만들기 위해서는?
# - 결과를 보게되면 띄어쓰기를 기준으로 나눠지게 되는게 정규식 표현대로 올바르게 출력된게 맞나?

# %%
import nltk
txt = txt = 'KoNLPy는 한국어 정보처리를 위한 파이썬 패키지입니다. 설치법은 이 곳을 참고해주세요. NLP를 처음 시작하시는 분들은 시작하기 에서 가볍게 기본 지식을 습득할 수 있습니다.'
words = nltk.regexp_tokenize(txt, r'\w+')
print(words)
# Out:
# ['KoNLPy는', '한국어', '정보처리를', '위한', '파이썬', '패키지입니다', '설치법은', '이', '곳을', '참고해주세요', 'NLP를', '처음', '시작하시는', '분들은', '시작하기', '에서', '가볍게', '기본', '지식을', '습득할', '수', '있습니다']

# %% [markdown]
# - 문장으로 토큰을 만들어보도록 하자
# - 문장으로 토큰을 만들기 위해서 쓰는 nltk의 메소드(?)는?
# - 문장으로 나눠지는 기준은?

# %%
sents = nltk.sent_tokenize(txt)
print(sents)
# Out:
# ['KoNLPy는 한국어 정보처리를 위한 파이썬 패키지입니다.', '설치법은 이 곳을 참고해주세요.', 'NLP를 처음 시작하시는 분들은 시작하기 에서 가볍게 기본 지식을 습득할 수 있습니다.']

# %% [markdown]
# - 아래는 뭐한거지?
# - PorterStemmer, WordNetLemmatizer, pos_tag의 역할은?
# - 품사를 확인하려면?

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tag import pos_tag

# %%
stemmer = PorterStemmer()
print([stemmer.stem(word) for word in words])
# Out:
# ['konlpy는', '한국어', '정보처리를', '위한', '파이썬', '패키지입니다', '설치법은', '이', '곳을', '참고해주세요', 'nlp를', '처음', '시작하시는', '분들은', '시작하기', '에서', '가볍게', '기본', '지식을', '습득할', '수', '있습니다']

# %%
lemm = WordNetLemmatizer()
print([lemm.lemmatize(word, pos='v') for word in words])
# Out:
# ['KoNLPy는', '한국어', '정보처리를', '위한', '파이썬', '패키지입니다', '설치법은', '이', '곳을', '참고해주세요', 'NLP를', '처음', '시작하시는', '분들은', '시작하기', '에서', '가볍게', '기본', '지식을', '습득할', '수', '있습니다']

# %%
# 품사를 확인해보자 --> 다 명사로 나온다. 왜 ? 
pos_tag(words)
# Out:
# [('KoNLPy는', 'NNP'),
#  ('한국어', 'NNP'),
#  ('정보처리를', 'NNP'),
#  ('위한', 'NNP'),
#  ('파이썬', 'NNP'),
#  ('패키지입니다', 'NNP'),
#  ('설치법은', 'NNP'),
#  ('이', 'NNP'),
#  ('곳을', 'NNP'),
#  ('참고해주세요', 'NNP'),
#  ('NLP를', 'NNP'),
#  ('처음', 'NNP'),
#  ('시작하시는', 'NNP'),
#  ('분들은', 'NNP'),
#  ('시작하기', 'NNP'),
#  ('에서', 'NNP'),
#  ('가볍게', 'NNP'),
#  ('기본', 'NNP'),
#  ('지식을', 'NNP'),
#  ('습득할', 'NNP'),
#  ('수', 'NNP'),
#  ('있습니다', 'NN')]

# %% [markdown]
# - 한국어 처리를 위해서 파이썬 패키지가 등장하였다.
# - 그것이 바로 KoNLPy[코엔엘파이]이다.
# - URL : http://KoNLPy.org/ko/latest/

# %% [markdown]
# ## 62.2 설치를 해보자.
# - 1. 우선 자바가 설치 되어 있어야 한다.
#     - 홈페이지가서 다운로드해서 설정
#     - 이때 환경변수 설정도 잘 해줘야 한다.
# - 2. 파이썬에서 자바 모듈을 호출하기 위한 연동 패키지로 JPype1가 필요하다.
#     - pip install JPype1==0.7.0
# - 3. KoNLPy를 설치해보자
#     - pip install konlpy

# %%
# !java -version
# Out:
# java version "1.8.0_291"
# Java(TM) SE Runtime Environment (build 1.8.0_291-b10)
# Java HotSpot(TM) 64-Bit Server VM (build 25.291-b10, mixed mode)

# %%
# !pip install JPype1==0.7.0
# Out:
# Collecting JPype1==0.7.0
#   Using cached JPype1-0.7.0.tar.gz (470 kB)
# Building wheels for collected packages: JPype1
#   Building wheel for JPype1 (setup.py) ... done
#   Created wheel for JPype1: filename=JPype1-0.7.0-cp37-cp37m-macosx_10_9_x86_64.whl size=244729 sha256=d3200227ed60a70fd7d3ce0fa272606162fd5aeb2f53da971a418c6367c6f467
#   Stored in directory: /Users/master90/Library/Caches/pip/wheels/45/f6/69/bbaf10d063569d5222f95652e667526bf08ae916dff2fa8782
# Successfully built JPype1
# Installing collected packages: JPype1
# Successfully installed JPype1-0.7.0

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Using cached konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
# Collecting tweepy>=3.7.0
#   Using cached tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Collecting colorama
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4==4.6.0
#   Using cached beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
# Requirement already satisfied: JPype1>=0.7.0 in /opt/anaconda3/envs/tf2/lib/python3.7/site-packages (from konlpy) (0.7.0)
# Requirement already satisfied: numpy>=1.6 in /opt/anaconda3/envs/tf2/lib/python3.7/site-packages (from konlpy) (1.20.2)
# Collecting lxml>=4.1.0
#   Using cached lxml-4.6.3-cp37-cp37m-macosx_10_9_x86_64.whl (4.5 MB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting requests[socks]>=2.11.1
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied: six>=1.10.0 in /opt/anaconda3/envs/tf2/lib/python3.7/site-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/tf2/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: urllib3, idna, chardet, requests, PySocks, oauthlib, requests-oauthlib, tweepy, lxml, colorama, beautifulsoup4, konlpy
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.6.0 chardet-4.0.0 colorama-0.4.4 idna-2.10 konlpy-0.5.2 lxml-4.6.3 oauthlib-3.1.0 requests-2.25.1 requests-oauthlib-1.3.0 tweepy-3.10.0 urllib3-1.26.4

# %% [markdown]
# ## 62.3 코엔엘파이가제공하는 형태소분석기
# - 형태소 분석기 사전이란?
#     - 형태소 분석 함수들을 제공하는 모듈을 형태소
#
#
# - 코엔엘파이가 제공하는 5개의 형태소 분석기 클래스가 있다.
#     - 1) Hannanum(한나눔)
#     - 2) Kkma(꼬꼬마)
#     - 3) Komoran(코모란)
#     - 4) Mecab(메카브)
#     - 5) okt(Open Korean Text)
#     - 비교해보기 : https://konlpy-ko.readthedocs.io/ko/v0.5.2/morph/
#
#
# - 메소드는 아래와 같다.
# |번호|메소드|설명|
# |--|--|--|
# |1|morphs(str)|형태소 단위로 토큰화(tokenize)|
# |2|nouns(str)|명사만 추출하여 토큰화(tokenize)|
# |3|pos(str)|품사 부착|
# |4|tagset|형태소 분석기가 사용하는 품사태그 설명하는 속성.|

# %%
# 코모란과 okt 클래스를 사용해보도록하자.
txt = '''[강병수 / 낚시꾼 구조 시민 : 거기 세 분 중에 다 내가 들어갈게. 내가 들어갈게. 이렇게 말씀하셨는데, 그래도 거기서 제가 나이가 제일 어려서, 제가 들어가겠다고 하고.]
무사히 구조를 마친 강 씨, 그런데 다시 바다로 뛰어듭니다.
뒤집힌 보트까지 꺼내옵니다.
구조를 지켜보던 일행이 화면으로 보기에도 이상하리 만치 침착했던 건 모두 수상안전 전문가였기 때문이었습니다.
구조된 남성은 일행이 가져온 옷으로 체온을 유지해 안정을 취했고, 무사히 귀가한 것으로 전해졌습니다.'''

# %%
# 1) okt 사용해보기 
from konlpy.tag import Okt
okt = Okt()

# 형태소 단위로 토큰화 해보자 
tokens = okt.morphs(txt)
print('- 토큰 갯수 : ',len(tokens))
print(tokens)

# 명사만 추출해보자 
noun_tokens = okt.nouns(txt)
print('- 명사 갯수 : ',len(noun_tokens))
print(noun_tokens)

# 품사를 확인해보자 
pos_tokens = okt.pos(txt)
print('- 품사확인 : \n',pos_tokens)

# 단어와 품사를 같이 봐보자 
pos_tokens2 = okt.pos(txt, join=True)
print('- 품사 확인2 :  \n', pos_tokens2)

# 해당 품사가 어떤 것지 확인해보자 
okt.tagset

# norm은 Okt만 있는 기능 : norm=True 
print(okt.morphs('이것도 되나욬ㅋㅋㅋㅋㅋ'))
print(okt.morphs('이것도 되나욬ㅋㅋㅋㅋㅋ', norm=True))
print(okt.morphs('반갑습니당',norm=True))
# Out:
# - 토큰 갯수 :  107
# ['[', '강병수', '/', '낚시꾼', '구조', '시민', ':', '거기', '세', '분', '중', '에', '다', '내', '가', '들어갈게', '.', '내', '가', '들어갈게', '.', '이렇게', '말씀', '하셨는데', ',', '그래도', '거기', '서', '제', '가', '나이', '가', '제일', '어려서', ',', '제', '가', '들어가겠다고', '하고', '.]', '\n', '무사히', '구조', '를', '마친', '강', '씨', ',', '그런데', '다시', '바다로', '뛰어듭니', '다', '.', '\n', '뒤집힌', '보트', '까지', '꺼내옵니다', '.', '\n', '구조', '를', '지켜보던', '일행', '이', '화면', '으로', '보기', '에도', '이상하리', '만치', '침착했던', '건', '모두', '수상', '안전', '전문가', '였기', '때문', '이었습니다', '.', '\n', '구조', '된', '남성은', '일행', '이', '가져온', '옷', '으로', '체온', '을', '유지', '해', '안정', '을', '취했', '고', ',', '무사히', '귀가', '한', '것', '으로', '전해졌습니다', '.']
# - 명사 갯수 :  44
# ['강병수', '낚시꾼', '구조', '시민', '거기', '세', '분', '중', '내', '내', '말씀', '거기', '제', '나이', '제일', '제', '구조', '강', '씨', '다시', '바다로', '뛰어듭니', '뒤집힌', '보트', '구조', '일행', '화면', '보기', '건', '모두', '수상', '안전', '전문가', '때문', '구조', '남성은', '일행', '옷', '체온', '유지', '안정', '취했', '귀가', '것']
# - 품사확인 :
#  [('[', 'Punctuation'), ('강병수', 'Noun'), ('/', 'Punctuation'), ('낚시꾼', 'Noun'), ('구조', 'Noun'), ('시민', 'Noun'), (':', 'Punctuation'), ('거기', 'Noun'), ('세', 'Noun'), ('분', 'Noun'), ('중', 'Noun'), ('에', 'Josa'), ('다', 'Adverb'), ('내', 'Noun'), ('가', 'Josa'), ('들어갈게', 'Verb'), ('.', 'Punctuation'), ('내', 'Noun'), ('가', 'Josa'), ('들어갈게', 'Verb'), ('.', 'Punctuation'), ('이렇게', 'Adverb'), ('말씀', 'Noun'), ('하셨는데', 'Verb'), (',', 'Punctuation'), ('그래도', 'Adverb'), ('거기', 'Noun'), ('서', 'Josa'), ('제', 'Noun'), ('가', 'Josa'), ('나이', 'Noun'), ('가', 'Josa'), ('제일', 'Noun'), ('어려서', 'Verb'), (',', 'Punctuation'), ('제', 'Noun'), ('가', 'Josa'), ('들어가겠다고', 'Verb'), ('하고', 'Verb'), ('.]', 'Punctuation'), ('\n', 'Foreign'), ('무사히', 'Adjective'), ('구조', 'Noun'), ('를', 'Josa'), ('마친', 'Verb'), ('강', 'Noun'), ('씨', 'Noun'), (',', 'Punctuation'), ('그런데', 'Conjunction'), ('다시', 'Noun'), ('바다로', 'Noun'), ('뛰어듭니', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('뒤집힌', 'Noun'), ('보트', 'Noun'), ('까지', 'Josa'), ('꺼내옵니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('구조', 'Noun'), ('를', 'Josa'), ('지켜보던', 'Verb'), ('일행', 'Noun'), ('이', 'Josa'), ('화면', 'Noun'), ('으로', 'Josa'), ('보기', 'Noun'), ('에도', 'Josa'), ('이상하리', 'Adjective'), ('만치', 'Josa'), ('침착했던', 'Adjective'), ('건', 'Noun'), ('모두', 'Noun'), ('수상', 'Noun'), ('안전', 'Noun'), ('전문가', 'Noun'), ('였기', 'Verb'), ('때문', 'Noun'), ('이었습니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('구조', 'Noun'), ('된', 'Verb'), ('남성은', 'Noun'), ('일행', 'Noun'), ('이', 'Josa'), ('가져온', 'Verb'), ('옷', 'Noun'), ('으로', 'Josa'), ('체온', 'Noun'), ('을', 'Josa'), ('유지', 'Noun'), ('해', 'Verb'), ('안정', 'Noun'), ('을', 'Josa'), ('취했', 'Noun'), ('고', 'Josa'), (',', 'Punctuation'), ('무사히', 'Adjective'), ('귀가', 'Noun'), ('한', 'Josa'), ('것', 'Noun'), ('으로', 'Josa'), ('전해졌습니다', 'Verb'), ('.', 'Punctuation')]
# - 품사 확인2 :
#  ['[/Punctuation', '강병수/Noun', '//Punctuation', '낚시꾼/Noun', '구조/Noun', '시민/Noun', ':/Punctuation', '거기/Noun', '세/Noun', '분/Noun', '중/Noun', '에/Josa', '다/Adverb', '내/Noun', '가/Josa', '들어갈게/Verb', './Punctuation', '내/Noun', '가/Josa', '들어갈게/Verb', './Punctuation', '이렇게/Adverb', '말씀/Noun', '하셨는데/Verb', ',/Punctuation', '그래도/Adverb', '거기/Noun', '서/Josa', '제/Noun', '가/Josa', '나이/Noun', '가/Josa', '제일/Noun', '어려서/Verb', ',/Punctuation', '제/Noun', '가/Josa', '들어가겠다고/Verb', '하고/Verb', '.]/Punctuation', '\n/Foreign', '무사히/Adjective', '구조/Noun', '를/Josa', '마친/Verb', '강/Noun', '씨/Noun', ',/Punctuation', '그런데/Conjunction', '다시/Noun', '바다로/Noun', '뛰어듭니/Noun', '다/Josa', './Punctuation', '\n/Foreign', '뒤집힌/Noun', '보트/Noun', '까지/Josa', '꺼내옵니다/Verb', './Punctuation', '\n/Foreign', '구조/Noun', '를/Josa', '지켜보던/Verb', '일행/Noun', '이/Josa', '화면/Noun', '으로/Josa', '보기/Noun', '에도/Josa', '이상하리/Adjective', '만치/Josa', '침착했던/Adjective', '건/Noun', '모두/Noun', '수상/Noun', '안전/Noun', '전문가/Noun', '였기/Verb', '때문/Noun', '이었습니다/Verb', './Punctuation', '\n/Foreign', '구조/Noun', '된/Verb', '남성은/Noun', '일행/Noun', '이/Josa', '가져온/Verb', '옷/Noun', '으로/Josa', '체온/Noun', '을/Josa', '유지/Noun', '해/Verb', '안정/Noun', '을/Josa', '취했/Noun', '고/Josa', ',/Punctuation', '무사히/Adjective', '귀가/Noun', '한/Josa', '것/Noun', '으로/Josa', '전해졌습니다/Verb', './Punctuation']
# ['이', '것', '도', '되나욬', 'ㅋㅋㅋㅋㅋ']
# ['이', '것', '도', '되나요', 'ㅋㅋㅋ']
# ['반갑습니다']

# %%
#2) Komoran 
from konlpy.tag import Komoran
kom = Komoran()

tokens = kom.morphs(txt)
noun_token = kom.nouns(txt)
pos_token = kom.pos(txt)
kom.tagset
# kom.morphs(txt, norm = True) :  norm은 Okt에만 있다. 

print('- 토큰 갯수 : ',len(tokens))
print('- 명사 갯수 : ',len(noun_token))
print('- 단어 10개 품사확인 : \n',pos_token[:10])
print('- 품사 확인 : \n',kom.tagset)
# Out:
# - 토큰 갯수 :  138
# - 명사 갯수 :  37
# - 단어 10개 품사확인 :
#  [('[', 'SS'), ('강병수', 'NNP'), ('/', 'SP'), ('낚시', 'NNG'), ('꾼', 'XSN'), ('구조 시', 'NNP'), ('민', 'NNP'), (':', 'SP'), ('거기', 'NP'), ('세', 'MM')]
# - 품사 확인 :
#  {'EC': '연결 어미', 'EF': '종결 어미', 'EP': '선어말어미', 'ETM': '관형형 전성 어미', 'ETN': '명사형 전성 어미', 'IC': '감탄사', 'JC': '접속 조사', 'JKB': '부사격 조사', 'JKC': '보격 조사', 'JKG': '관형격 조사', 'JKO': '목적격 조사', 'JKQ': '인용격 조사', 'JKS': '주격 조사', 'JKV': '호격 조사', 'JX': '보조사', 'MAG': '일반 부사', 'MAJ': '접속 부사', 'MM': '관형사', 'NA': '분석불능범주', 'NF': '명사추정범주', 'NNB': '의존 명사', 'NNG': '일반 명사', 'NNP': '고유 명사', 'NP': '대명사', 'NR': '수사', 'NV': '용언추정범주', 'SE': '줄임표', 'SF': '마침표, 물음표, 느낌표', 'SH': '한자', 'SL': '외국어', 'SN': '숫자', 'SO': '붙임표(물결,숨김,빠짐)', 'SP': '쉼표,가운뎃점,콜론,빗금', 'SS': '따옴표,괄호표,줄표', 'SW': '기타기호 (논리수학기호,화폐기호)', 'VA': '형용사', 'VCN': '부정 지정사', 'VCP': '긍정 지정사', 'VV': '동사', 'VX': '보조 용언', 'XPN': '체언 접두사', 'XR': '어근', 'XSA': '형용사 파생 접미사', 'XSN': '명사파생 접미사', 'XSV': '동사 파생 접미사'}

# %% [markdown]
# ## 62.4 연습1 - 코엔엘파이말뭉치 --> kolaw, kobill 로 예시
# - 코엔엘파이 말뭉치로 kolaw, kobill이 있다.
#     - kolaw : 대한민국 헌법 말뭉치
#         - constitution.txt
#     - kobill : 대한민국 국회 의안 말뭉치
#         - 1809890.txt ~ 1809899.txt

# %%
from konlpy.corpus import kolaw, kobill

# 1) kolaw 확인

kolaw.fileids() # kolaw에 존재하는 파일 - ['constitution.txt'] 
constitution = kolaw.open('constitution.txt') # 파일열어서 로드
constitution.read() # 읽어보기 

# 2) kobill 확인
kobill.fileids() # kobill에 존재하는 파일들 
bill = kobill.open('1809896.txt')
bill.read()
# Out:
# '행정절차법 일부개정법률안\n\n(유선호의원 대표발의 )\n\n 의 안\n 번 호\n\n9896\n\n발의연월일 : 2010.  11.  15.\n\n발  의  자 : 유선호․강기갑․김효석  \n\n최문순ㆍ최재성ㆍ조영택  \n\n김성곤ㆍ문학진ㆍ백재현  \n\n송민순ㆍ양승조ㆍ신낙균  \n\n조배숙ㆍ박은수ㆍ정동영  \n\n김춘진ㆍ김재윤ㆍ우윤근  \n\n이성남ㆍ박영선 의원\n\n             (20인)\n\n제안이유\n\n  현행법은 입법예고와 행정예고를 통하여 정책 결정 과정에 국민 참\n\n여의 절차를 규정하고 있기는 하나 실제 정책 결정·집행·평가의 단계\n\n에서 근본적인 국민 참여 규정은 거의 없어 위임입법에 의하여 정책 \n\n결정 및 집행 권한이 부여되는 문제점이 있음.\n\n  따라서 입법예고 이전의 국민적 협의절차와 재입법예고 규정 등을 \n\n신설하고, 당사자 등의 개념을 명확히 하여 당사자의 신청에 의한 청\n\n문의 기회를 보장하는 한편, 법령상의 일부 미비점을 개선․보완함으\n\n- 1 -\n\n\x0c- 2 -\n\n로써 실질적인 국민 참여의 기회를 보장하여 행정에 대한 국민의 불\n\n신을 없애고 행정의 투명성을 확보하려는 것임.   \n\n주요내용\n\n  가. 법의 적용 제외 대상을 대통령령으로 정할 수 없게 하는 대신에 \n\n법에서 상세하게 규정하도록 함(안 제3조).\n\n  나. 당사자의 개념을 명확히 하고, 당사자의 신청에 의하여 청문을 \n\n실시할 수 있도록 함(안 제2조제4호, 제22조제1항제1호의2 신설). \n\n  다. 법제처장은 입법예고를 하지 아니한 법령안의 심사를 반려할 수 \n\n있도록 하고, 법령안 주관기관의 장은 입법예고 후 예고내용에 \n\n중요한 변경이 발생하거나 국민생활과 직접 관련되는 내용이 추\n\n가되는 경우에는 재입법예고를 하도록 함(안 제41조제4항 및 제5\n\n항 신설).\n\n  라. 입법예고기간과 행정예고기간을 50일 이상으로 연장함(안 제43\n\n조 및 제46조의2).\n\n  마. 행정청은 입법이 필요하다고 판단하는 경우 입법 계획을 수립하\n\n여 관계 기관, 관련 단체, 이해당사자 및 국회와 사전에 협의하고 \n\n의견을 듣도록 함(안 제43조의2 신설).\n\n  \n\n\x0c법률  제        호\n\n행정절차법 일부개정법률안\n\n행정절차법 일부를 다음과 같이 개정한다.\n\n제2조제4호를 다음과 같이 한다.\n\n  4. "당사자등"이라 함은 행정청의 처분에 대하여 직접 그 상대가 되\n\n는 당사자와 행정청의 행위에 의하여 법률상 또는 사실상 이해관\n\n계에 영향을 받는 자로서 이해관계인을 말한다.\n\n제3조제2항제9호를 다음과 같이 하고, 같은 항에 제10호부터 제19호까\n\n지를 각각 다음과 같이 신설한다.\n\n  9. 「병역법」, 「향토예비군 설치법」, 「민방위기본법」, 「비상대\n\n비자원 관리법」에 따른 징집·소집·동원·훈련에 관한 사항\n\n  10. 외국인의 출입국·난민인정·귀화·국적회복에 관한 사항\n\n  11. 공무원 인사 관계 법령에 의한 징계, 그 밖의 처분에 관한 사항\n\n  12. 이해조정을 목적으로 법령에 의한 알선·조정·중재·재정, 그 밖의 \n\n처분에 관한 사항\n\n  13. 조세 관계 법령에 의한 조세의 부과·징수에 관한 사항\n\n  14. 「독점규제 및 공정거래에 관한 법률」, 「하도급거래 공정화에 \n\n- 3 -\n\n\x0c- 4 -\n\n관한 법률」, 「약관의 규제에 관한 법률」에 따라 공정거래위원\n\n회의 의결·결정을 거쳐 행하는 사항\n\n  15. 「국가배상법」, 「공익사업을 위한 토지 등의 취득 및 보상에 \n\n관한 법률」에 따른 재결·결정에 관한 사항\n\n  16. 학교·연수원 등에서 교육·훈련의 목적을 달성하기 위하여 학생·\n\n연수생 등을 대상으로 행하는 사항\n\n  17. 사람의 학식·기능에 관한 시험·검정의 결과에 따라 행하는 사항\n\n  18. 「배타적 경제수역에서의 외국인어업 등에 대한 주권적 권리의 \n\n행사에 관한 법률」에 따라 행하는 사항\n\n  19. 「특허법」, 「실용신안법」, 「디자인보호법」, 「상표법」에 \n\n따른 사정·결정·심결, 그 밖의 처분에 관한 사항\n\n제22조제1항에 제1호의2를 다음과 같이 신설한다.\n\n  1의2. 당사자의 신청이 있는 경우\n\n제41조제4항을 제6항으로 하고, 같은 조에 제4항 및 제5항을 각각 다\n\n음과 같이 신설한다.\n\n  ④ 법제처장은 다음 각 호의 어느 하나에 해당하는 법령안이 심사 \n\n요청된 때에는 그 사유를 명시하여 이를 반려할 수 있다. 이 경우 \n\n제3호부터 제5호까지에 해당하는 경우에는 법령안 주관기관의 장과 \n\n협의하여야 한다.\n\n  1. 제1항에 따른 입법예고절차를 거치지 아니한 법령안 \n\n  2. 정부입법계획에 포함되지 아니한 법령안\n\n\x0c  3. 헌법에 위반될 소지가 있거나 법리적으로 명백한 문제가 있다고 \n\n인정되는 법령안\n\n  4. 정부정책의 변경 등 사정변경으로 인하여 내용이 재검토될 필요\n\n가 있다고 인정되는 법령안\n\n  5. 그 밖에 입법추진일정을 재검토할 필요가 있는 등 특별한 사유가 \n\n있는 법령안\n\n  ⑤ 입법안을 마련한 행정청은 입법예고 후 예고내용에 중요한 변경\n\n이 발생하거나 국민생활과 직접 관련되는 내용이 추가되는 경우에\n\n는 해당 부분에 대한 입법예고를 다시 하여야 한다. 이 경우 긴급히 \n\n처리되어야 하는 법령안에 대하여 제1항 단서에 따라 입법예고를 \n\n생략하고자 하거나 특별한 사정으로 인하여 입법예고기간을 50일 \n\n미만으로 단축하고자 하는 때에는 법제처장과 협의하여야 한다.\n\n제43조 중 “20일이상”을 “50일 이상”으로 한다.\n\n제43조의2를 다음과 같이 신설한다.\n\n제43조의2(협의단계) ① 행정청은 국민의 생명과 안전 및 재산 등에 \n\n관련한 중요한 사항에 대한 국제협상 등 입법이 필요하다고 판단하\n\n는 경우 입법 계획을 수립하여 관계 기관, 관련 단체, 이해당사자 \n\n및 국회와 사전에 협의하고 의견을 들어야 한다.\n\n  ② 행정청은 입법에 관하여 관계 기관의 장과 협의를 필요로 하는 \n\n경우 특별한 사정이 없는 한 그 내용을 국민에게 공개하여야 한다.\n\n제46조를 다음과 같이 한다.\n\n- 5 -\n\n\x0c- 6 -\n\n제46조(행정예고) ① 행정청은 정책·제도 및 계획(이하 “정책등”이라 \n\n한다)을 수립·시행하거나 변경하고자 하는 때에는 이를 예고하여야 \n\n한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 예고를 \n\n하지 아니할 수 있다.\n\n  1. 정책등의 내용이 국민의 권리·의무 또는 일상생활과 관련이 없는 \n\n경우\n\n  2. 정책등이 긴급을 요하는 경우\n\n  3. 상위 법령등의 단순한 집행을 위한 경우\n\n  4. 예고함이 공익을 현저히 해할 우려가 있는 경우\n\n  ② 정책등이 고시·훈령·지침·예규 등(이하 “고시등”이라 한다)의 제\n\n정·개정 또는 폐지를 수반하는 경우 행정청은 그 내용을 함께 예고\n\n하여야 한다.\n\n  ③ 제1항에도 불구하고 법령등의 입법을 포함하는 행정예고의 경우\n\n에는 입법예고로 이를 갈음할 수 있다.\n\n제46조의2부터 제46조의4까지를 각각 다음과 같이 신설한다.\n\n제46조의2(예고기간) 행정예고기간은 예고내용의 성격 등을 고려하여 \n\n정하되, 특별한 사정이 없는 한 50일 이상으로 한다.\n\n제46조의3(협의단계) ① 행정청은 정책등의 수립·시행 또는 변경이 필\n\n요하다고 판단하는 경우 기획 등 초기단계부터 그 정보를 국민에게 \n\n공개하고 국민의 적극적 참여를 도모하고자 노력하여야 한다.\n\n  ② 행정청은 정책등의 수립·시행 또는 변경에 관하여 관계 기관의 \n\n\x0c장과 협의를 필요로 하는 경우 특별한 사정이 없는 한 그 협의 내\n\n용을 국민에게 공개하여야 한다.\n\n제46조의4(행정예고 통계와 확인 등) ① 행정청은 매년 자신이 행한 \n\n행정예고의 실시현황과 그 결과에 관한 통계를 ...

# %% [markdown]
# - 프로세스 :
#     - (1) 임포트 및 객체생성
#     - (2) 토큰화
#     - (3) 처리
#     - (4) 시각화 : matplotlib, WordCloud

# %%
from nltk import Text
from konlpy.corpus import kolaw
from konlpy.tag import Komoran

kom = Komoran()
# Out:
# ---------------------------------------------------------------------------
# java.lang.OutOfMemoryError                Traceback (most recent call last)
# <ipython-input-65-abc617bcbaad> in <module>
#       3 from konlpy.tag import Komoran
#       4
# ----> 5 kom = Komoran()
#
# /opt/anaconda3/envs/tf2/lib/python3.7/site-packages/konlpy/tag/_komoran.py in __init__(self, jvmpath, userdic, modelpath, max_heap_size)
#     104
#     105         try:
# --> 106             self.jki = komoranJavaPackage.Komoran(self.modelpath)
#     107         except TypeError:  # Package kr.lucypark.komoran.KomoranInterface is not Callable
#     108             raise IOError("Cannot access komoran-dic. Please leave an issue at https://github.com/konlpy/konlpy/issues")
#
# /opt/anaconda3/envs/tf2/lib/python3.7/site-packages/jpype/_jobject.py in __init__(self, *args)
#      93             object.__setattr__(self, '__javavalue__', args[0])
#      94         elif not hasattr(self, '__javavalue__'):
# ---> 95             jv = self.__class__.__javaclass__.newInstance(*args)
#      96             object.__setattr__(self, '__javavalue__', jv)
#      97         super(JObject, self).__init__()
#
# java.lang.OutOfMemoryError: GC overhead limit exceeded
