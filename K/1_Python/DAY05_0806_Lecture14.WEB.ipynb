# %%
# day05 피피티 p.39부터

# %% [markdown]
# # HTML
# - XML형태로 웹페이지의 구조를 표현
# - 뷰티풀숩등 XML 파서로 해석 가능
# - 다운로드 HTML파일을 웹 브라우저가 해석 & 화면 표시

# %% [markdown]
# # Requests
# - 웹페이지를 읽기 위해서 일반적으로 Request라이브러리 사용

# %%
import requests

URL = 'https://www.naver.com'
response = requests.get(URL) # GET으로 접근

print(response.status_code) # 상태코드
print(response.text) #
# Out:
# 200
#
# ...

# %% [markdown]
# # Crawling
# -

# %%
import requests 
from bs4 import BeautifulSoup 

URL = 'https://sports.news.naver.com/index'

response = requests.get(URL)
print(response.status_code)
# Out:
# 200
